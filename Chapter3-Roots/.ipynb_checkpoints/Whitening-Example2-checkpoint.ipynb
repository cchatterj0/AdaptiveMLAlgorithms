# %%
# This code is written to support the experiments in the book titled:
# "Adaptive Machine Learning Algorithms with Python"
# by
# Chanchal Chatterjee
# December 2021
#
# Experiments for Chapter 2 - Mean skeleton with MNIST data
#
# Author: Chanchal Chatterjee
#

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

import tensorflow as tf

# %%
# Extract the number "0" from keras mnist dataset into array X[nDim, nSamples]

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# (unique, counts) = np.unique(y_train, return_counts=True)
# frequencies = np.asarray((unique, counts)).T
# print(frequencies)

X1 = np.zeros(shape=(1,784))
for i in range(x_train.shape[0]):
    if (y_train[i] == 0):
        X1 = np.vstack([X1, x_train[i].flatten()])
for i in range(x_test.shape[0]):
    if (y_test[i] == 0):
        X1 = np.vstack([X1, x_test[i].flatten()])
X = X1.T
X = np.delete(X,(0), axis=1)
X.shape
# Out:
# (784, 6903)

# %%
# Plot original images
# image_array is np.array(num_images, x_size, y_size)

import matplotlib.pyplot as plt

def plot_images(image_array):
    fig, axarr = plt.subplots(6,4, figsize=(8, 12))
    for i in range(6):
        for j in range(4):
            #axarr[i,j].set_title('Image-'+str(4*i+j))
            img = np.reshape(image_array[:,4*i+j],(-1,28))
            axarr[i,j].imshow(img[:,:], cmap='gist_gray')

# %%
#Plot the original data
plot_images(X)

# %%
# Compute the first 200 principal components and PCA whiten the data
# Whiten the data for identity correlation
from scipy.linalg import eigh

nSamples = X.shape[1]
nDim = X.shape[0]
corX = (X @ X.T) / nSamples
eigvals, eigvecs = eigh(corX)
#print("eigvals =\n", eigvals[::-1])

V  = np.fliplr(eigvecs)
D = np.zeros(shape=(nDim,nDim))
for i in range(nDim):
    if (eigvals[::-1][i] < 100):
        D[i,i] = 0
    else:
        D[i,i] = np.sqrt(1/eigvals[::-1][i])
# np.sqrt(1/eigvals[::-1]))

# Identity Covariance whitened data
Z = V @ D @ V.T @ X

# %%
# Plot the identity whitened data
plot_images(Z)

# %%
# Plot the EVD data
import seaborn as sns
corX = (X @ X.T)/nSamples
corY = (Z @ Z.T)/nSamples
plt.figure(figsize=(10, 4))
plt.rcParams.update({'font.size': 8})
plt.subplot(1, 2, 1)
#plt.imshow(corX, interpolation='nearest', cmap='RdBu')
sns.heatmap(corX, cmap='gray', cbar=False)
plt.title("Original data")
plt.axis('off')
plt.subplot(1, 2, 2)
#plt.imshow(corY, interpolation='nearest', cmap='hot')
sns.heatmap(corY, cmap='gray', cbar=False)
plt.title("Whitened data")
plt.axis('off')
plt.show()

# %%
# Plot Figure 3.2
plt.rcParams.update({'font.size': 12})
fig, axarr = plt.subplots(4, 4, figsize=(16, 16))
for i in range(4):
    for j in range(4):
        img = np.reshape(X[:,4*i+j],(-1,28))
        axarr[i,j].imshow(img[:,:], cmap='gist_gray')

plt.figure(figsize=(10, 10))
sns.heatmap(corX, cmap='gray', cbar=False)
plt.axis('off')
# Out:
# (0.0, 784.0, 784.0, 0.0)

# %%
# Plot Figure 3.3
plt.rcParams.update({'font.size': 12})
fig, axarr = plt.subplots(4, 4, figsize=(16, 16))
for i in range(4):
    for j in range(4):
        img = np.reshape(Z[:,4*i+j],(-1,28))
        axarr[i,j].imshow(img[:,:], cmap='gist_gray')

plt.figure(figsize=(10, 10))
sns.heatmap(corY, cmap='gray', cbar=False)
plt.axis('off')
# Out:
# (0.0, 784.0, 784.0, 0.0)
